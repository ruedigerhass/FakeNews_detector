# %%
reset -fs

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import glob
from sklearn import tree
import os

# %%
xtree = ET.parse('articles/0000.xml')
xroot = xtree.getroot()

# %%
import pandas as pd
import xml.etree.ElementTree as et

def parse_XML(xml_file, df_cols): 
    """Parse the input XML file and store the result in a pandas 
    DataFrame with the given columns. 
    
    The first element of df_cols is supposed to be the identifier 
    variable, which is an attribute of each node element in the 
    XML data; other features will be parsed from the text content 
    of each sub-element. 
    """
    
    xtree = et.parse(xml_file)
    xroot = xtree.getroot()
    rows = []
    
    for node in xroot: 
        res = []
        res.append(node.attrib.get(df_cols[0]))
        for el in df_cols[0:]: 
            if node is not None and node.find(el) is not None:
                res.append(node.find(el).text)
            else: 
                res.append(None)
        rows.append({df_cols[i]: res[i] 
                     for i, _ in enumerate(df_cols)})
    
    out_df = pd.DataFrame(rows, columns=df_cols)
        
    return out_df

# %%
df_cols = ['mainText']

# %%
parse_XML('articles/0000.xml', df_cols)
# Out:
#    mainText
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
# 30     None
# 31     None
# 32     None
# 33     None
# 34     None
# 35     None
# 36     None
# 37     None
# 38     None
# 39     None
# 40     None
# 41     None
# 42     None
# 43     None
# 44     None
# 45     None
# 46     None
# 47     None
# 48     None
# 49     None
# 50     None
# 51     None
# 52     None
# 53     None
# 54     None
# 55     None
# 56     None
# 57     None

# %%
def read_files(df_cols):
    #For each xml file return a matrix of values asked for
    path = 'articles/'
    for filename in os.listdir(path):
        data_row = []
        if not filename.endswith('.xml'): continue
        xmlfile = os.path.join(path, filename)
        tree = ET.parse(xmlfile)

# %%
import pandas as pd 
import xml.etree.ElementTree as et 

path = 'articles/'
df_cols = ["mainText", "orientation", "veracity", "portal"]

for filename in os.listdir(path):
    data_row = []
    #if not filename.endswith('.xml'): continue
    xmlfile = os.path.join(path, filename)
    #tree = ET.parse(xmlfile)

    xtree = et.parse(xmlfile)
    xroot = xtree.getroot() 
    res = []
    rows = []
    for node in xroot: 
        s_text = tree.find("mainText").text
        s_orient = tree.find("orientation").text if node is not None else None
        s_veracity = tree.find("veracity").text if node is not None else None
        s_portal = tree.find("portal").text if node is not None else None
        #res.append(s_text)
        #res.append(s_orient)
        #res.append(s_veracity)
        #res.append(s_portal)
        #rows.append({df_cols[i]: res[i] 
        #             for i, _ in enumerate(df_cols)})
        rows.append({"mainText": s_text, "orientation": s_orient, 
                     "veracity": s_veracity, "portal": s_portal})

    out_df = pd.DataFrame(rows, columns = df_cols)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-387-e066e6bc8ba6> in <module>
#      16     rows = []
#      17     for node in xroot:
# ---> 18         s_text = tree.find("mainText").text
#      19         s_orient = tree.find("orientation").text if node is not None else None
#      20         s_veracity = tree.find("veracity").text if node is not None else None
#
# AttributeError: module 'sklearn.tree' has no attribute 'find'

# %%
read_files(df_cols)

# %%
out_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-389-3f3fc8d0ee74> in <module>
# ----> 1 out_df
#
# NameError: name 'out_df' is not defined

# %%
import pandas as pd 
import xml.etree.ElementTree as et 
from sklearn import tree

path = 'articles/'
df_cols = ["mainText", "orientation", "veracity", "portal"]

for filename in os.listdir(path):
    if not filename.endswith('.xml'): continue
    xmlfile = os.path.join(path, filename)

    xtree = et.parse(xmlfile)
    xroot = xtree.getroot() 
    res = []
    for node in xroot: 
        if df_cols == "mainText":
             tree.find("mainText").text = res.append(s_text)        
        elif df_cols == "orientation":
             tree.find("orientation").text = res.append(s_orient)          
        elif df_cols == "veracity":
             tree.find('veracity').text = res.append(s_veracity)
        elif df_cols == "portal":
             tree.find('portal').text = res.append(s_portal)
                                
    out_df = pd.DataFrame(res, columns = df_cols)

# %%
out_df
# Out:
# Empty DataFrame
# Columns: [mainText, orientation, veracity, portal]
# Index: []
